# %%
import sys
sys.path
sys.path.append('/Users/alpha/Documents/GitHub/QT/')

# %%
from analysis.market_analysis import cn_st_month_market_analysis

# %%
dict_data = {'A02090Z02_yd': '平板玻璃产量累计值(万重量箱)'}
cn_st_month_market_analysis(code_dict=dict_data, plot_type=None, title=list(dict_data.values())[0])
dict_data = {'A02090Z01_yd': '平板玻璃产量当期值(万重量箱)'}
cn_st_month_market_analysis(code_dict=dict_data, plot_type=None, title=list(dict_data.values())[0])

# %%
dict_data = {"A02090L01_yd":"纯碱（碳酸钠）产量当期值(万吨)"}
cn_st_month_market_analysis(code_dict=dict_data, plot_type=None, title=list(dict_data.values())[0])
dict_data = {"A02090L02_yd":"纯碱（碳酸钠）累加值(万吨)"}
cn_st_month_market_analysis(code_dict=dict_data, plot_type=None, title=list(dict_data.values())[0])

# %%
dict_data = {"A060101_yd":"房地产投资累计值(亿元)"}
cn_st_month_market_analysis(code_dict=dict_data, plot_type=None, title=list(dict_data.values())[0])
dict_data = {'A060405_yd': '房地产竣工面积累计值(万平方米)'}
cn_st_month_market_analysis(code_dict=dict_data, plot_type=None, title=list(dict_data.values())[0])
dict_data = {'A060401_yd': '房地产施工面积累计值(万平方米)'}
cn_st_month_market_analysis(code_dict=dict_data, plot_type=None, title=list(dict_data.values())[0])

# %%
dict_data = {"A02092301_yd":"汽车产量当期值(万辆)"}
cn_st_month_market_analysis(code_dict=dict_data, plot_type=None, title=list(dict_data.values())[0])
dict_data = {"A02092302_yd":"汽车产量累计值(万辆)"}
cn_st_month_market_analysis(code_dict=dict_data, plot_type=None, title=list(dict_data.values())[0])

# %%
dict_data = {"A02092E01_yd":"太阳能电池（光伏电池）产量当期值(万千瓦)"}
cn_st_month_market_analysis(code_dict=dict_data, plot_type=None, title=list(dict_data.values())[0])
dict_data = {"A02092E02_yd":"太阳能电池（光伏电池）产量累计值(万千瓦)"}
cn_st_month_market_analysis(code_dict=dict_data, plot_type=None, title=list(dict_data.values())[0])
